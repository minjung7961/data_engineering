# %%
# %matplotlib inline
import matplotlib.pyplot as plt


y = [1,2,3,4,5]
plt.plot(y)
plt.show()

# %%
y = [13, 16, 15, 18, 16, 17, 16]
x = [130,160,150,180,160,170,160]
plt.plot(range(len(y)),y*10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-3944b6c921f1> in <module>
#       1 y = [13, 16, 15, 18, 16, 17, 16]
# ----> 2 plt.plot(range(len(y)),y*10)
#
# c:\users\ad\appdata\local\programs\python\python38\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2986 @_copy_docstring_and_deprecators(Axes.plot)
#    2987 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2988     return gca().plot(
#    2989         *args, scalex=scalex, scaley=scaley,
#    2990         **({"data": data} if data is not None else {}), **kwargs)
#
# c:\users\ad\appdata\local\programs\python\python38\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...
